# %% [markdown]
# # Portfolio Assignment 6: Pokémon Dataset

# %%
import pandas as pd

# %%
Pokemon = pd.read_csv('files/All_Pokemon.csv')

# %%
Pokemon.head()
# Out:
#    Number           Name Type 1  Type 2                    Abilities  HP  Att  \
# 0       1      Bulbasaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  45   49
# 1       2        Ivysaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  60   62
# 2       3       Venusaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  80   82
# 3       3  Mega Venusaur  Grass  Poison                ['Thick Fat']  80  100
# 4       4     Charmander   Fire     NaN     ['Blaze', 'Solar Power']  39   52
#
#    Def  Spa  Spd  ...  Against Bug  Against Rock  Against Ghost  \
# 0   49   65   65  ...          1.0           1.0            1.0
# 1   63   80   80  ...          1.0           1.0            1.0
# 2   83  100  100  ...          1.0           1.0            1.0
# 3  123  122  120  ...          1.0           1.0            1.0
# 4   43   60   50  ...          0.5           2.0            1.0
#
#    Against Dragon  Against Dark Against Steel  Against Fairy  Height  Weight  \
# ...

# %% [markdown]
# ## 1. Number of Pokémon type occurrences

# %%
pokemon_with_one_type = Pokemon[Pokemon['Type 2'].isnull()]
pokemon_with_two_types = Pokemon[Pokemon['Type 2'].notnull()]

two_type_value_counts = pokemon_with_two_types['Type 2'].value_counts() + pokemon_with_two_types['Type 1'].value_counts()
total = pokemon_with_one_type['Type 1'].value_counts() + two_type_value_counts

total.plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2. Average HP per Pokémon type

# %%
pokemon_with_one_type = Pokemon[Pokemon['Type 2'].isnull()]
pokemon_with_two_types = Pokemon[Pokemon['Type 2'].notnull()]

total = pokemon_with_one_type.groupby('Type 1')['HP'].mean() + pokemon_with_two_types.groupby('Type 1')['HP'].mean() + pokemon_with_two_types.groupby('Type 2')['HP'].mean()
total.astype(int).plot.barh()
# Out:
# <AxesSubplot:ylabel='Type 1'>

# %% [markdown]
# ## 3. Average Pokemon HP

# %%
Pokemon["HP"].median()
# Out:
# 67.0

# %%
Pokemon["HP"].mean()
# Out:
# 69.90600775193798

# %%
Pokemon["HP"].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4. Average Pokemon Attack

# %%
Pokemon["Att"].median()
# Out:
# 78.0

# %%
Pokemon["Att"].mean()
# Out:
# 80.52616279069767

# %%
Pokemon["Att"].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 5. Number of Pokémon per generation

# %%
Pokemon['Generation'].value_counts().sort_index().plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 6. How many Pokémon have a legendary status?

# %%
Pokemon['Legendary'].value_counts().plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***Note: 0.0 = Non Legendary, 1.0 = Legendary**
