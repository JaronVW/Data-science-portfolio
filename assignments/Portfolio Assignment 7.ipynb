# %% [markdown]
# # Assignment 7

# %%
import pandas as pd
Pokemon = pd.read_csv("../files/all_Pokemon.csv")

# %% [markdown]
# ## 1. Distribution of Pokemon HP

# %%
Pokemon["HP"].plot(kind="hist", bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# This histogram can be classified as a normal distribution, the histogram goes up in the middle with the outliers on both ends. When changing the number of bins we can see this trend persists:

# %%
Pokemon["HP"].plot(kind="hist", bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## 2. Distribution of Pokemon Attack

# %%
Pokemon["Att"].plot(kind="hist", bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Pokémon Attack also shows a normal distribution as shown above
