# %% [markdown]
# # Assignment 14

# %%
import pandas as pd
Pokemon = pd.read_csv('../files/All_Pokemon.csv')

# %%
def create_contingency_table(dataset, column1, column2):
    return dataset.groupby([column1, column2]).size().unstack(column1, fill_value=0)

from scipy.stats import chi2_contingency
def check_cat_vs_cat_correlation(dataset, column1, column2):
    contingency_table = create_contingency_table(dataset, column1, column2)
    chi2 = chi2_contingency(contingency_table)
    p_value = chi2[1]
    odds_of_correlation = 1 - p_value
    print(f"The odds of a correlation between {column1} and {column2} is {odds_of_correlation * 100}% (Based on a p value of {p_value}).")
    print("This percentage needs to be at least 95% for a significant correlation.")

# %% [markdown]
# # 1. Contingency table for Type 1 and Legendary status

# %% [markdown]
# I Expect that there will be a correlation between Type 1 and Legendary status.

# %%
Pokemon = Pokemon.dropna()

# %%
create_contingency_table(Pokemon, 'Experience type', 'Type 1')
# Out:
# Experience type  Erratic  Fast  Fluctuating  Medium Fast  Medium Slow  Slow
# Type 1
# Bug                    3     4            0           38            9     8
# Dark                   0     0            0           14            6    12
# Dragon                 2     0            0            0            0    27
# Electric               0     0            0           17            3     6
# Fairy                  0     2            0            0            0     1
# Fighting               0     0            0            6            2     5
# Fire                   0     0            0            9           17     5
# Flying                 0     0            0            3            1     0
# Ghost                  0     0            2           16            7     1
# Grass                  3     0            1            8           26    10
# Ground                 0     0            0           11            7     6
# ...

# %%
check_cat_vs_cat_correlation(Pokemon, 'Experience type', 'Legendary')
# Out:
# The odds of a correlation between Experience type and Legendary is 100.0% (Based on a p value of 1.1898220473225243e-42).
# This percentage needs to be at least 95% for a significant correlation.

# %%
create_contingency_table(Pokemon, 'Experience type', 'Type 1').plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='Type 1'>

# %% [markdown]
# There is a very strong correlation between Type 1 and Experience type. For example, bug type pokémon have a very high chance of being a medium fast experience type.

# %%
## 2. Contingency table for Type 1 and Type 2

# %% [markdown]
# NB: The following data will only contain pokémon that have two types.

# %%
Pokemon_two_types = Pokemon.dropna()

# %%
create_contingency_table(Pokemon_two_types, 'Type 1', 'Type 2')
# Out:
# Type 1    Bug  Dark  Dragon  Electric  Fairy  Fighting  Fire  Flying  Ghost  \
# Type 2
# Bug         0     0       0         0      0         0     2       0      0
# Dark        0     0       0         1      0         2     1       0      1
# Dragon      0     4       0         2      0         0     2       2      1
# Electric    4     0       1         0      0         0     0       0      0
# Fairy       2     3       1         2      0         0     0       0      1
# Fighting    4     2       2         0      0         0     7       0      0
# Fire        2     3       1         1      0         0     0       0      3
# Flying     14     6       6         6      2         2     7       0      3
# Ghost       1     2       4         1      0         1     2       0      0
# Grass       6     1       0         1      0         0     0       0     11
# Ground      2     0       7         0      0         0     3       0      2
# ...

# %%
check_cat_vs_cat_correlation(Pokemon_two_types, 'Type 1', 'Type 2')
# Out:
# The odds of a correlation between Type 1 and Type 2 is 100.0% (Based on a p value of 1.1723350860985682e-33).
# This percentage needs to be at least 95% for a significant correlation.

# %%
create_contingency_table(Pokemon_two_types, 'Type 1', 'Type 2').plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='Type 2'>

# %% [markdown]
# The bar plot is a bit hard to read, but it shows that there is also a very strong correlation between Type 1 and Type 2, this is the result I expected. With my experience playing the game there are certain type combinations that are very common. Pretty much every Pokemon game has a normal/flying type. Flying type is most often a secondary type too.
